# %%
### Importing packages

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
### Importing Dataset: Excel file

data = pd.read_excel("C:\\Users\\shri shibi\\Desktop\\NewDAB103-dataset.xlsx")

# %%
### No of rows and columns

data.shape
# Out:
# (4710, 20)

# %%
### Type of data in columns

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4710 entries, 0 to 4709
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Reporter Name                            4710 non-null   object
#  1   Partner Name                             4710 non-null   object
#  2   Partner Name id                          4710 non-null   int64
#  3   Year                                     4710 non-null   int64
#  4   Trade Flow                               4710 non-null   object
#  5   Product Group                            4710 non-null   object
#  6   Import (US$ Thousand)                    4710 non-null   float64
#  7   Import Product Share (%)                 4710 non-null   float64
#  8   AHS Weighted Average (%)                 4672 non-null   float64
#  9   AHS MaxRate (%)                          4672 non-null   float64
# ...

# %%
### Unique values:

data.nunique()
# Out:
# Reporter Name                                 1
# Partner Name                                230
# Partner Name id                             230
# Year                                          4
# Trade Flow                                    1
# Product Group                                 6
# Import (US$ Thousand)                      3619
# Import Product Share (%)                   1172
# AHS Weighted Average (%)                    975
# AHS MaxRate (%)                              53
# AHS MinRate (%)                              20
# AHS SpecificDuty Imports (US$ Thousand)      13
# AHS Dutiable Imports (US$ Thousand)        1987
# AHS Duty Free Imports (US$ Thousand)       3295
# MFN Weighted Average (%)                   1213
# MFN MaxRate (%)                              47
# MFN MinRate (%)                              22
# MFN SpecificDuty Imports (US$ Thousand)      13
# MFN Dutiable Imports (US$ Thousand)        2791
# MFN Duty Free Imports (US$ Thousand)       3136
# ...

# %%
### Count of null values in each column:

data.isnull().sum()
# Out:
# Reporter Name                               0
# Partner Name                                0
# Partner Name id                             0
# Year                                        0
# Trade Flow                                  0
# Product Group                               0
# Import (US$ Thousand)                       0
# Import Product Share (%)                    0
# AHS Weighted Average (%)                   38
# AHS MaxRate (%)                            38
# AHS MinRate (%)                            38
# AHS SpecificDuty Imports (US$ Thousand)    38
# AHS Dutiable Imports (US$ Thousand)        38
# AHS Duty Free Imports (US$ Thousand)       38
# MFN Weighted Average (%)                   38
# MFN MaxRate (%)                            38
# MFN MinRate (%)                            38
# MFN SpecificDuty Imports (US$ Thousand)    38
# MFN Dutiable Imports (US$ Thousand)        38
# MFN Duty Free Imports (US$ Thousand)       38
# dtype: int64

# %%
### Descriptive Statistics

data.describe()
# Out:
#        Partner Name id         Year  Import (US$ Thousand)  \
# count      4710.000000  4710.000000           4.710000e+03
# mean        106.775372  2016.506794           1.814330e+05
# std          62.984967     1.116802           1.274257e+06
# min           1.000000  2015.000000           0.000000e+00
# 25%          52.000000  2016.000000           2.670000e+00
# 50%         105.000000  2017.000000           1.412300e+02
# 75%         158.000000  2018.000000           6.794120e+03
# max         230.000000  2018.000000           2.357203e+07
#
#        Import Product Share (%)  AHS Weighted Average (%)  AHS MaxRate (%)  \
# count               4710.000000               4672.000000      4672.000000
# mean                   5.462671                  3.741398        21.730550
# std                   15.255557                 12.139946        74.712811
# min                    0.000000                  0.000000         0.000000
# ...

# %%
### Finding the relationship between variables

corr =data.corr()
corr
# Out:
#                                          Partner Name id      Year  \
# Partner Name id                                 1.000000 -0.007191
# Year                                           -0.007191  1.000000
# Import (US$ Thousand)                           0.115471 -0.002145
# Import Product Share (%)                        0.010583 -0.006414
# AHS Weighted Average (%)                       -0.070823 -0.018264
# AHS MaxRate (%)                                -0.051946 -0.019901
# AHS MinRate (%)                                 0.095543 -0.009031
# AHS SpecificDuty Imports (US$ Thousand)         0.037213 -0.036325
# AHS Dutiable Imports (US$ Thousand)             0.055787 -0.008262
# AHS Duty Free Imports (US$ Thousand)            0.116510 -0.002786
# MFN Weighted Average (%)                       -0.064082 -0.006302
# MFN MaxRate (%)                                -0.059639 -0.013337
# MFN MinRate (%)                                 0.100275 -0.004405
# ...

# %%
### Plotting the heat map for co-relation :

ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
### Creating the new dataframe to plot outliers :

boxplot_data1 = data.iloc[0:4711,5:14]
boxplot_data1
# Out:
#           Product Group  Import (US$ Thousand)  Import Product Share (%)  \
# 0                Animal                   3.15                      0.09
# 1                Animal                   2.24                      0.00
# 2                Animal               23184.17                      1.75
# 3                Animal                   0.27                      0.19
# 4                Animal              214615.34                     13.26
# ...                 ...                    ...                       ...
# 4705  Plastic or Rubber                   5.15                      0.88
# 4706  Plastic or Rubber                3293.14                      0.44
# 4707  Plastic or Rubber                   0.27                      0.00
# 4708  Plastic or Rubber                   0.10                      0.01
# 4709  Plastic or Rubber                   1.19                      0.03
#
#       AHS Weighted Average (%)  AHS MaxRate (%)  AHS MinRate (%)  \
# ...

# %%
### Plot the new dataframe to detect outliers :

boxplot_data1.boxplot()
plt.xticks(rotation=90)
plt.yscale('log')

# %%
### Creating the new dataframe to plot outliers :

boxplot_data2 = data.iloc[0:4711, 14:19]
boxplot_data2
# Out:
#       MFN Weighted Average (%)  MFN MaxRate (%)  MFN MinRate (%)  \
# 0                        68.26            237.5              0.0
# 1                         0.00              0.0              0.0
# 2                         0.75            295.5              0.0
# 3                         0.00              0.0              0.0
# 4                         7.24            245.5              0.0
# ...                        ...              ...              ...
# 4705                      3.33             15.5              0.0
# 4706                      2.21             15.5              0.0
# 4707                      4.38              6.5              0.0
# 4708                      2.20              6.5              0.0
# 4709                      4.51              6.5              0.0
#
#       MFN SpecificDuty Imports (US$ Thousand)  \
# 0                                         0.0
# 1                                         0.0
# ...

# %%
### Plot the new dataframe to detect outliers :

boxplot_data2.boxplot()
plt.xticks(rotation=90)
plt.yscale('log')

# %%
### Calculating outliers using statistics : for column [MFN MaxRate (%)]

q1 = data['MFN MaxRate (%)'].quantile(0.25)
q3 = data['MFN MaxRate (%)'].quantile(0.75)
iqr = q3-q1
print(q1,q3,iqr)
# Out:
# 6.5 18.0 11.5

# %%
lower_outlier = data['MFN MaxRate (%)'] < (q1-1.5*iqr)
upper_outlier = data['MFN MaxRate (%)'] > (q3+1.5*iqr)

# %%
data[upper_outlier]
# Out:
#     Reporter Name   Partner Name  Partner Name id  Year Trade Flow  \
# 0          Canada    Afghanistan                1  2018     Import
# 2          Canada      Argentina                3  2018     Import
# 4          Canada      Australia                5  2018     Import
# 5          Canada        Austria                6  2018     Import
# 6          Canada        Belgium                7  2018     Import
# ..            ...            ...              ...   ...        ...
# 659        Canada        Ukraine              154  2015     Import
# 661        Canada        Uruguay              156  2015     Import
# 662        Canada  United States              157  2015     Import
# 666        Canada          World              189  2015     Import
# 668        Canada   South Africa              162  2015     Import
#
#     Product Group  Import (US$ Thousand)  Import Product Share (%)  \
# 0          Animal                   3.15                      0.09
# ...

# %%
### Calculating outliers using statistics : for column [MFN Weighted Average (%)]

q1 = data['MFN Weighted Average (%)'].quantile(0.25)
q3 = data['MFN Weighted Average (%)'].quantile(0.75)
iqr = q3-q1
print(q1,q3,iqr)
# Out:
# 0.02 5.41 5.390000000000001

# %%
lower_outlier = data['MFN Weighted Average (%)'] < (q1-1.5*iqr)
upper_outlier = data['MFN Weighted Average (%)'] > (q3+1.5*iqr)

# %%
data[upper_outlier]
# Out:
#      Reporter Name            Partner Name  Partner Name id  Year Trade Flow  \
# 0           Canada             Afghanistan                1  2018     Import
# 5           Canada                 Austria                6  2018     Import
# 9           Canada                Bulgaria               10  2018     Import
# 17          Canada                  Brazil               18  2018     Import
# 20          Canada                  Bhutan               21  2018     Import
# ...            ...                     ...              ...   ...        ...
# 2328        Canada               Venezuela              158  2015     Import
# 2330        Canada                 Vietnam              159  2015     Import
# 2331        Canada                 Vanuatu              188  2015     Import
# 2333        Canada  Wallis and Futura Isl.              225  2015     Import
# 2334        Canada                   Samoa              160  2015     Import
#
# ...

# %%
### Calculating outliers using statistics : for column [AHS Weighted Average (%)]

q1 = data['AHS Weighted Average (%)'].quantile(0.25)
q3 = data['AHS Weighted Average (%)'].quantile(0.75)
iqr = q3-q1

lower_outlier = data['AHS Weighted Average (%)'] < (q1-1.5*iqr)
upper_outlier = data['AHS Weighted Average (%)'] > (q3+1.5*iqr)

data[upper_outlier]
# Out:
#      Reporter Name                Partner Name  Partner Name id  Year  \
# 0           Canada                 Afghanistan                1  2018
# 4           Canada                   Australia                5  2018
# 5           Canada                     Austria                6  2018
# 6           Canada                     Belgium                7  2018
# 9           Canada                    Bulgaria               10  2018
# ...            ...                         ...              ...   ...
# 4607        Canada                   Sri Lanka               87  2018
# 4630        Canada                    Malaysia              104  2018
# 4648        Canada                 Philippines              119  2018
# 4672        Canada                    Suriname              139  2018
# 4677        Canada  Saint Maarten (Dutch part)              214  2018
#
#      Trade Flow      Product Group  Import (US$ Thousand)  \
# 0        Import             Animal                   3.15
# ...

# %%
### Calculating outliers using statistics : for column [AHS MaxRate (%)]

q1 = data['AHS MaxRate (%)'].quantile(0.25)
q3 = data['AHS MaxRate (%)'].quantile(0.75)
iqr = q3-q1

lower_outlier = data['AHS MaxRate (%)'] < (q1-1.5*iqr)
upper_outlier = data['AHS MaxRate (%)'] > (q3+1.5*iqr)

data[upper_outlier]
# Out:
#     Reporter Name   Partner Name  Partner Name id  Year Trade Flow  \
# 0          Canada    Afghanistan                1  2018     Import
# 2          Canada      Argentina                3  2018     Import
# 4          Canada      Australia                5  2018     Import
# 5          Canada        Austria                6  2018     Import
# 6          Canada        Belgium                7  2018     Import
# ..            ...            ...              ...   ...        ...
# 659        Canada        Ukraine              154  2015     Import
# 661        Canada        Uruguay              156  2015     Import
# 662        Canada  United States              157  2015     Import
# 666        Canada          World              189  2015     Import
# 668        Canada   South Africa              162  2015     Import
#
#     Product Group  Import (US$ Thousand)  Import Product Share (%)  \
# 0          Animal                   3.15                      0.09
# ...

# %%
### Calculating outliers using statistics : for column [Import Product Share (%)]

q1 = data['Import Product Share (%)'].quantile(0.25)
q3 = data['Import Product Share (%)'].quantile(0.75)
iqr = q3-q1

lower_outlier = data['Import Product Share (%)'] < (q1-1.5*iqr)
upper_outlier = data['Import Product Share (%)'] > (q3+1.5*iqr)

data[upper_outlier]
# Out:
#      Reporter Name                   Partner Name  Partner Name id  Year  \
# 4           Canada                      Australia                5  2018
# 11          Canada                   Bahamas, The               12  2018
# 18          Canada                       Barbados               19  2018
# 23          Canada                          Chile               24  2018
# 32          Canada                         Cyprus               33  2018
# ...            ...                            ...              ...   ...
# 4656        Canada                        Romania              127  2018
# 4657        Canada             Russian Federation              128  2018
# 4662        Canada  Serbia, FR(Serbia/Montenegro)              131  2018
# 4683        Canada                       Thailand              146  2018
# 4702        Canada                        Vanuatu              188  2018
#
#      Trade Flow      Product Group  Import (US$ Thousand)  \
# ...

# %%
### Total no of records per country : column(Partner Name)

data['Partner Name'].value_counts().head(60)
# Out:
# Bolivia                          24
# Austria                          24
# Honduras                         24
# Korea, Rep.                      24
# Lebanon                          24
# Norway                           24
# Bahrain                          24
# France                           24
# Hong Kong, China                 24
# Guatemala                        24
# Netherlands                      24
# Czech Republic                   24
# Ukraine                          24
# Jamaica                          24
# Pakistan                         24
# Ghana                            24
# Slovak Republic                  24
# Panama                           24
# Madagascar                       24
# Malaysia                         24
# Namibia                          24
# Uganda                           24
# Russian Federation               24
# Belarus                          24
# Philippines                      24
# Barbados                         24
# ...

# %%
### Total no of records per country : column(Partner Name)

data['Partner Name'].value_counts().tail(60)
# Out:
# Tonga                             18
# Eswatini                          18
# Iraq                              18
# British Virgin Islands            18
# Central African Republic          17
# Christmas Island                  17
# Uzbekistan                        17
# Azerbaijan                        17
# Andorra                           17
# Aruba                             17
# Guam                              17
# Grenada                           17
# Brunei                            17
# Nauru                             16
# Cape Verde                        16
# Turkmenistan                      16
# Kyrgyz Republic                   16
# Vanuatu                           16
# Saint Pierre and Miquelon         16
# Bhutan                            16
# American Samoa                    16
# Eritrea                           16
# St. Vincent and the Grenadines    15
# Cocos (Keeling) Islands           15
# Comoros                           15
# ...

# %%
### Plot for Product group category:

sns.countplot(x = 'Product Group',data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Animal'),
#   Text(1, 0, 'Stone and Glass'),
#   Text(2, 0, 'Textiles'),
#   Text(3, 0, 'Agricultural Raw Materials'),
#   Text(4, 0, 'Wood'),
#   Text(5, 0, 'Plastic or Rubber')])

# %%
### Plot for Import (US$ Thousand)

sns.stripplot(y = data['Import (US$ Thousand)'])
plt.ylim(0,999)
#plt.yscale('log')
# Out:
# (0.0, 999.0)

# %%
### Plot for Import (US$ Thousand)

sns.stripplot(y = data['Import (US$ Thousand)'])
plt.ylim(1000, 30000000)
# Out:
# (1000.0, 30000000.0)

# %%
### Plot for Import (MFN Duty Free Imports (US$ Thousand))

sns.stripplot(y = data['MFN Duty Free Imports (US$ Thousand)'])
#plt.yscale('log')
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
### Plot for Import (MFN Duty Free Imports (US$ Thousand))

sns.stripplot(y = data['MFN Duty Free Imports (US$ Thousand)'])
plt.ylim(501,12791095)
# Out:
# (501.0, 12791095.0)

# %%
### Plot for Import (AHS Duty Free Imports (US$ Thousand))

sns.stripplot(y = data['AHS Duty Free Imports (US$ Thousand)'])
#plt.yscale('log')
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
### Plot for Import (AHS Duty Free Imports (US$ Thousand))

sns.stripplot(y = data['AHS Duty Free Imports (US$ Thousand)'])
plt.ylim(501,18674272)
# Out:
# (501.0, 18674272.0)
